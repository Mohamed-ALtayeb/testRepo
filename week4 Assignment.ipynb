# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Mohamed Altaieb</strong>
# <p>Front End Web Developer</p>

# %% [markdown]
# <i>I am interested in data science because this field has the problem solving , statistical analysis and all the things i like</i>

# %% [markdown]
# <h3>The code below lists the numbers from 1 to 10 in an array</h3>

# %%
print(list(i for i in range(1,10)))

# %% [markdown]
# <p>Bulleted List</p>
# <ul>
#     <li>IBM</li>
#     <li>Watson</li>
#     <li>Studio</li>
# </ul>
# </hr>
# <a src="https://www.twitter.com">Twitter</a>
# </hr>
# <img src="https://images.unsplash.com/photo-1453728013993-6d66e9c9123a?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8MXx8bGVuc3xlbnwwfHwwfHw%3D&w=1000&q=80"></img>
# </hr>
# <q>Yes</q>
# </hr>
# <p>Welcome to <mark>Jumanji</mark></p>
# <p>I am using <s>javascript</s> python </p>
